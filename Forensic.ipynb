# %%
# Clone the github repository
# !git clone https://github.com/Cesco16/Nanopore_Sequencing_Lab.git

# %%
# Move to the cloned repository
# %cd Nanopore_Sequencing_Lab
# !ls -la

# %%
# Istall condacolab
# !pip install -q condacolab
import condacolab
condacolab.install()

# %%
# update conda env with the SV.yaml file

# !conda env update -n base -f /content/Nanopore_Sequencing_Lab/forensic.yaml

# %%
# DOWNLOAD THE SEQUENCING DATA AND THE REFERENCES
# %cd Nanopore_Sequencing_Lab
# !wget https://zenodo.org/records/20801287/files/suspect1.fastq
# !wget https://zenodo.org/records/20801287/files/suspect2.fastq
# !wget https://zenodo.org/records/20801287/files/suspect3.fastq
# !wget https://zenodo.org/records/20801287/files/guilty.fastq
# !wget https://zenodo.org/records/20801287/files/chrM_T2T.fasta
# !wget https://zenodo.org/records/20801287/files/chr11_T2T.fasta
# !wget https://zenodo.org/records/20801287/files/chr2_T2T.fasta
# !wget https://zenodo.org/records/20801287/files/chr5_T2T.fasta

# %%
# !mv /content/Nanopore_Sequencing_Lab/suspect1.fastq /content/Nanopore_Sequencing_Lab/T.fastq
# !mv /content/Nanopore_Sequencing_Lab/suspect2.fastq /content/Nanopore_Sequencing_Lab/M.fastq
# !mv /content/Nanopore_Sequencing_Lab/suspect3.fastq /content/Nanopore_Sequencing_Lab/C.fastq

# %%
# %%bash
#
# # Alignment with minimap2 to mtDNA

# %%
# %%bash
#
# # Samtools sorting and indexing

# %%
# %%bash
# # Variant calling with bcftools

# %%
# %%bash
#
# # MATCHING

# %%
###### STR
# %%bash

# Alignment to chr2, chr5 and chr11

# %%
# %%bash
#
# # samtools sorting and indexing

# %%
# %%bash
#
# # SV calling with sniffles

# %%
# %%bash
# cd /content/Nanopore_Sequencing_Lab/
#
# echo "=========================================================="
# echo "  FASE 1: CONCATENAZIONE DEI CROMOSOMI (bcftools concat)  "
# echo "=========================================================="
#
# # Concatenazione (se i file globali esistono già, bcftools li sovrascriverà senza problemi)
# bcftools concat guilty_chr2.vcf guilty_chr5.vcf guilty_chr11.vcf -o guilty_all.vcf
# bcftools concat T_chr2.vcf T_chr5.vcf T_chr11.vcf -o T_all.vcf
# bcftools concat M_chr2.vcf M_chr5.vcf M_chr11.vcf -o M_all.vcf
# bcftools concat C_chr2.vcf C_chr5.vcf C_chr11.vcf -o C_all.vcf

# %%
# %%bash
#
# # MATCHING
